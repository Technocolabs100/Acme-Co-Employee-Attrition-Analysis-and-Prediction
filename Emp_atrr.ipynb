# %% [markdown]
# ## Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the dataset

# %%
data = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")  # using csv file

# %% [markdown]
# ## Data Exploration
# ##### This step to ensure about the columns and row present
# ##### Here, check head, tail of the dataset.
# ##### checks the data description
# ##### Checks data type

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
pd.set_option('display.max_columns', None) ## displays all columns 
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# #### Checks whether dataset has missing values

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Checks dataset has null values
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#Describtive statitics
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data['Age'].mean()
# Out:
# 36.923809523809524

# %% [markdown]
# #### CHECK DUPLICATES

# %%
print(data.duplicated().value_counts())
data.drop_duplicates(inplace=True)
print(len(data))
# Out:
# False    1470
# Name: count, dtype: int64
# 1470

# %% [markdown]
# ### Observation
# ###### Data set having two data types int and string.
# ###### There is no any missing value in data set.
# ###### There is no any duplicate value also
# ###### There is no any missing value in dataset.

# %% [markdown]
# ### Target variable

# %%
plt.rc("font",size=10)
plt.figure(figsize=(10,3))
sns.countplot(y='Attrition', data=data)
plt.show()

# %% [markdown]
# ##### Column has imbalanced data

# %% [markdown]
# ### Exploatory analysis of data

# %%
# Attrition rate across the  department

plt.figure(figsize=(12,5))
sns.countplot(x='Department', hue='Attrition', data=data, palette='hot')
plt.title("Attrition based on department")
plt.show()

# %% [markdown]
# ### Observation
# ##### Compare to Sales and H & R department, employee attrion rate highest in the department of Research and development department

# %%
# Create a pivot table for the plot
pivot_data = data.pivot_table(index='Department', columns='Attrition', aggfunc='size', fill_value=0)

# Plot stacked bar plot
pivot_data.plot(kind='bar', figsize=(12, 5))
plt.title("Attrition based on Department")
plt.ylabel("Number of Employees")
plt.show()

# %%
#Attrition rate across the EducationField

plt.figure(figsize=(12,5))
sns.countplot(x='EducationField', hue='Attrition', data=data, palette='hot')
plt.title("Attrition based on EducationField")
plt.show()

# %%
#Attrition rate across the MaritalStatus

plt.figure(figsize=(12,5))
sns.countplot(x='MaritalStatus', hue='Attrition', data=data, palette='hot')
plt.title("Attrition based on MaritalStatus")
plt.show()

# %%
#Attrition rate across the JobRole

plt.figure(figsize=(20,4))
sns.countplot(x='JobRole', hue='Attrition', data=data, palette='hot')
plt.title("Attrition based on JobRole")
plt.show()

# %%
#Attrition rate across the  Gender

plt.figure(figsize=(9,5))
sns.countplot(x='Gender', hue='Attrition', data=data, palette='hot')
plt.title("Attrition based on Gender")
plt.show()

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
data['Attrition']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
data['count'] = 1

# %%
data.groupby(["Gender","Attrition"]).agg({"count":"sum"})
# Out:
#                   count
# Gender Attrition
# Female No           501
#        Yes           87
# Male   No           732
#        Yes          150

# %%
87/(501+87)
# Out:
# 0.14795918367346939

# %%
150/(732+150)
# Out:
# 0.17006802721088435

# %%
data['count'] = 1

# %%
data.groupby(["JobRole","Attrition"]).agg({"count":"sum"})
# Out:
#                                      count
# JobRole                   Attrition
# Healthcare Representative No           122
#                           Yes            9
# Human Resources           No            40
#                           Yes           12
# Laboratory Technician     No           197
#                           Yes           62
# Manager                   No            97
#                           Yes            5
# Manufacturing Director    No           135
#                           Yes           10
# Research Director         No            78
#                           Yes            2
# Research Scientist        No           245
#                           Yes           47
# Sales Executive           No           269
#                           Yes           57
# Sales Representative      No            50
#                           Yes           33

# %%
data.groupby(["EducationField","Attrition"]).agg({"count":"sum"})
# Out:
#                             count
# EducationField   Attrition
# Human Resources  No            20
#                  Yes            7
# Life Sciences    No           517
#                  Yes           89
# Marketing        No           124
#                  Yes           35
# Medical          No           401
#                  Yes           63
# Other            No            71
#                  Yes           11
# Technical Degree No           100
#                  Yes           32

# %%
data.groupby(["Department","Attrition"]).agg({"count":"sum"})
# Out:
#                                   count
# Department             Attrition
# Human Resources        No            51
#                        Yes           12
# Research & Development No           828
#                        Yes          133
# Sales                  No           354
#                        Yes           92

# %% [markdown]
# ### Observation
# ###### Employee in Reserch and development are more
# ###### Employee who working in sales deartment who leave the jo early

# %%
#Based on Age

plt.figure(figsize=(9,5))
sns.histplot(data=data, x='Age', kde=True, bins=20)
plt.title("Distribution of Age")
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
ordinal_features = ['Education','EnvironmentSatisfaction','JobInvolvement','JobSatisfaction','PerformanceRating','RelationshipSatisfaction','WorkLifeBalance']
data[ordinal_features].head()
# Out:
#    Education  EnvironmentSatisfaction  JobInvolvement  JobSatisfaction  \
# 0          2                        2               3                4
# 1          1                        3               2                2
# 2          2                        4               2                3
# 3          4                        4               3                3
# 4          1                        1               3                2
#
#    PerformanceRating  RelationshipSatisfaction  WorkLifeBalance
# 0                  3                         1                1
# 1                  4                         4                3
# 2                  3                         2                3
# 3                  3                         3                3
# 4                  3                         4                3

# %%
edu = {1:'Below College', 2: 'Collage', 3:'Bachelor',4:'Master',5:'Docter'}
plt.figure(figsize=(9,5))
sns.countplot(x=data['Education'].map(edu), hue='Attrition', data=data, palette='hot')
plt.title("Attrition based on Gender")
plt.show()

# %% [raw]
# Data Encoding

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
#Target variable --> Attrition
data['Attrition'] = data['Attrition'].replace({'No':0,'Yes':1})

# %%
data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
data['OverTime'] = data['OverTime'].replace({'No':0,'Yes':1})
data['Gender'] = data['Gender'].replace({'Male':0,'Female':1})
data['Over18'] = data['Over18'].replace({'No':0,'Y':1})

# %%
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               1              1               1
# 1          1               1              1               2
# 2          2               4              1               4
# 3          4               1              1               5
# 4          1               3              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %%
data['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# 2    1043
# 1     277
# 0     150
# Name: count, dtype: int64

# %%
data['JobRole'].value_counts()
# Out:
# JobRole
# 7    326
# 6    292
# 2    259
# 4    145
# 0    131
# 3    102
# 8     83
# 5     80
# 1     52
# Name: count, dtype: int64

# %%
data['EducationField'].value_counts()
# Out:
# EducationField
# 1    606
# 3    464
# 2    159
# 5    132
# 4     82
# 0     27
# Name: count, dtype: int64

# %%
data['Department'].value_counts()
# Out:
# Department
# 1    961
# 2    446
# 0     63
# Name: count, dtype: int64

# %%
data['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# 1    673
# 2    470
# 0    327
# Name: count, dtype: int64

# %% [markdown]
# #### For this situation we use the method
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoding_cols = ['BusinessTravel','JobRole','EducationField','Department','MaritalStatus']
label_encode = {}
for col in encoding_cols:
     label_encode[col] = LabelEncoder() # The process is identify the unique integer for each categories.
     data[col] = label_encode[col].fit_transform(data[col])

# %%
data.head(10)
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
# 5   32          0               1       1005           1                 2
# 6   59          0               2       1324           1                 3
# 7   30          0               2       1358           1                24
# 8   38          0               1        216           1                23
# 9   36          0               2       1299           1                27
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               1              1               1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int64
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...
